# %%
import pandas as pd

df = pd.read_csv("IoD-2025-custom_data_download-LAD (1).csv")

df = df.rename(columns={
    "Local Authority District code (2024)": "LAD_CODE",
    "Local Authority District name (2024)": "LAD_NAME",
    "Index of Multiple Deprivation (IMD) Rank": "IMD_RANK",
    "Income Rank": "INCOME_RANK",
    "Employment Rank": "EMPLOYMENT_RANK",
    "Education Skills and Training Rank": "EDUCATION_RANK",
    "Health Deprivation and Disability Rank": "HEALTH_RANK",
    "Crime Rank": "CRIME_RANK",
    "Barriers to Housing and Services Rank": "HOUSING_BARRIERS_RANK",
    "Living Environment Rank": "LIVING_ENVIRONMENT_RANK",
    "Income Deprivation Affecting Children Index (IDACI) Rank": "IDACI_RANK",
    "Income Deprivation Affecting Older People (IDAOPI) Rank": "IDAOPI_RANK"
})

df.to_csv("imd_lad_clean.csv", index=False)

print(df.head())
# Out:
#     LAD_CODE         LAD_NAME  IMD_RANK  INCOME_RANK  EMPLOYMENT_RANK  \
# 0  E06000053  Isles of Scilly       221          296              296
# 1  E06000063       Cumberland        98          158              107
# 2  E06000009        Blackpool         1           10                1
# 3  E07000119            Fylde       188          191              149
# 4  E07000128             Wyre       150          149               99
#
#    EDUCATION_RANK  HEALTH_RANK  CRIME_RANK  HOUSING_BARRIERS_RANK  \
# 0             293          296         296                     13
# 1              89           67         155                    126
# 2               9            1           2                    254
# 3             213          109         218                    215
# 4             178           69         180                    242
#
#    LIVING_ENVIRONMENT_RANK  IDACI_RANK  IDAOPI_RANK
# 0                        1         296          296
# ...
